# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests 
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
#retrive API key
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})  

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
   
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | batagay-alyta
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | pasighat
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | mega
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | saurimo
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | leh
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | arona
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | lasa
# Processing Record 20 of Set 1 | troitskoye
# Processing Record 21 of Set 1 | ayagoz
# Processing Record 22 of Set 1 | strasshof
# City not found. Skipping...
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | itaberai
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | carutapera
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | kahului
# Processing Record 31 of Set 1 | ambilobe
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | bilibino
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | husavik
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | peniche
# Processing Record 42 of Set 1 | conde
# Processing Record 43 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 1 | solnechnyy
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | cortes
# Processing Record 8 of Set 2 | bermeo
# Processing Record 9 of Set 2 | tautira
# Processing Record 10 of Set 2 | luang prabang
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | mogadishu
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | picos
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | te anau
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | mount gambier
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 2 | muros
# Processing Record 22 of Set 2 | ericeira
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | hinton
# Processing Record 27 of Set 2 | santa cruz do capibaribe
# Processing Record 28 of Set 2 | soubre
# Processing Record 29 of Set 2 | brooks
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | tres de maio
# Processing Record 33 of Set 2 | portland
# Processing Record 34 of Set 2 | dong hoi
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | mouzakion
# City not found. Skipping...
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | veraval
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | nemuro
# Processing Record 41 of Set 2 | corinto
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | chihuahua
# Processing Record 44 of Set 2 | faya
# Processing Record 45 of Set 2 | sisimiut
# Processing Record 46 of Set 2 | bonavista
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | olot
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | evensk
# Processing Record 2 of Set 3 | ukwa
# Processing Record 3 of Set 3 | machilipatnam
# Processing Record 4 of Set 3 | ulladulla
# Processing Record 5 of Set 3 | ahipara
# Processing Record 6 of Set 3 | saint-junien
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | kidal
# Processing Record 10 of Set 3 | churapcha
# Processing Record 11 of Set 3 | mananjary
# Processing Record 12 of Set 3 | port lincoln
# Processing Record 13 of Set 3 | maridi
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | makinsk
# Processing Record 16 of Set 3 | aasiaat
# Processing Record 17 of Set 3 | porto velho
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | sechura
# Processing Record 20 of Set 3 | aklavik
# Processing Record 21 of Set 3 | mutare
# Processing Record 22 of Set 3 | morondava
# Processing Record 23 of Set 3 | zaraza
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | saint-francois
# Processing Record 26 of Set 3 | manzhouli
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | hingoli
# Processing Record 29 of Set 3 | cua
# Processing Record 30 of Set 3 | caravelas
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 3 | xuddur
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | denpasar
# Processing Record 36 of Set 3 | japura
# Processing Record 37 of Set 3 | pangody
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | grand baie
# Processing Record 40 of Set 3 | bredasdorp
# Processing Record 41 of Set 3 | wakkanai
# Processing Record 42 of Set 3 | arrifes
# Processing Record 43 of Set 3 | rawah
# Processing Record 44 of Set 3 | thinadhoo
# Processing Record 45 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 46 of Set 3 | kati
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | njinikom
# Processing Record 49 of Set 3 | awbari
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | koumac
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 4 | pangai
# Processing Record 6 of Set 4 | gbarnga
# Processing Record 7 of Set 4 | palanga
# Processing Record 8 of Set 4 | gat
# Processing Record 9 of Set 4 | pokosnoye
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | guadalupe y calvo
# Processing Record 13 of Set 4 | porto novo
# Processing Record 14 of Set 4 | vestmannaeyjar
# Processing Record 15 of Set 4 | krasnoslobodsk
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | aras
# Processing Record 18 of Set 4 | erenhot
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | nioro
# Processing Record 22 of Set 4 | porosozero
# Processing Record 23 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 4 | necochea
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | penalva
# Processing Record 27 of Set 4 | businga
# Processing Record 28 of Set 4 | faanui
# Processing Record 29 of Set 4 | betioky
# Processing Record 30 of Set 4 | tubigan
# Processing Record 31 of Set 4 | gunnedah
# Processing Record 32 of Set 4 | guangyuan
# Processing Record 33 of Set 4 | havre-saint-pierre
# Processing Record 34 of Set 4 | borujan
# City not found. Skipping...
# Processing Record 35 of Set 4 | magaria
# Processing Record 36 of Set 4 | maputo
# Processing Record 37 of Set 4 | sandakan
# Processing Record 38 of Set 4 | comodoro rivadavia
# Processing Record 39 of Set 4 | okato
# Processing Record 40 of Set 4 | champerico
# Processing Record 41 of Set 4 | yalvac
# Processing Record 42 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 43 of Set 4 | norman wells
# Processing Record 44 of Set 4 | costa rica
# Processing Record 45 of Set 4 | mastic beach
# Processing Record 46 of Set 4 | mecca
# Processing Record 47 of Set 4 | khromtau
# Processing Record 48 of Set 4 | tateyama
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | zyryanka
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | egvekinot
# Processing Record 5 of Set 5 | sambava
# Processing Record 6 of Set 5 | port hedland
# Processing Record 7 of Set 5 | novopskov
# Processing Record 8 of Set 5 | kodiak
# Processing Record 9 of Set 5 | san pedro
# Processing Record 10 of Set 5 | bandarbeyla
# Processing Record 11 of Set 5 | clemencia
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | ramon castilla
# Processing Record 14 of Set 5 | olafsvik
# Processing Record 15 of Set 5 | verkhnevilyuysk
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | bowen
# Processing Record 18 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 5 | yatou
# Processing Record 21 of Set 5 | alofi
# Processing Record 22 of Set 5 | san quintin
# Processing Record 23 of Set 5 | hosdurga
# Processing Record 24 of Set 5 | rocha
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | colares
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | lompoc
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | carnarvon
# Processing Record 32 of Set 5 | kyshtovka
# Processing Record 33 of Set 5 | taunsa
# Processing Record 34 of Set 5 | moosomin
# Processing Record 35 of Set 5 | victoria
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | zhanaozen
# Processing Record 38 of Set 5 | pelym
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | havoysund
# Processing Record 41 of Set 5 | north myrtle beach
# Processing Record 42 of Set 5 | plouzane
# Processing Record 43 of Set 5 | sao filipe
# Processing Record 44 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 5 | srednekolymsk
# Processing Record 46 of Set 5 | aksarka
# Processing Record 47 of Set 5 | baicheng
# Processing Record 48 of Set 5 | kyra
# Processing Record 49 of Set 5 | camacha
# Processing Record 50 of Set 5 | charters towers
# Processing Record 1 of Set 6 | asau
# Processing Record 2 of Set 6 | chirongui
# Processing Record 3 of Set 6 | ascension
# Processing Record 4 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 6 | puyang
# Processing Record 6 of Set 6 | chapais
# Processing Record 7 of Set 6 | baghdad
# Processing Record 8 of Set 6 | adrar
# Processing Record 9 of Set 6 | pitimbu
# Processing Record 10 of Set 6 | kloulklubed
# Processing Record 11 of Set 6 | cuamba
# Processing Record 12 of Set 6 | kaitangata
# Processing Record 13 of Set 6 | progreso
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | orangeburg
# Processing Record 16 of Set 6 | krasnoselkup
# Processing Record 17 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 18 of Set 6 | kuantan
# Processing Record 19 of Set 6 | san vicente
# Processing Record 20 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | orekhovo-zuevo
# Processing Record 23 of Set 6 | pekan
# Processing Record 24 of Set 6 | yanam
# Processing Record 25 of Set 6 | union
# Processing Record 26 of Set 6 | cockburn town
# Processing Record 27 of Set 6 | nayoro
# Processing Record 28 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | buta
# Processing Record 31 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 6 | dengzhou
# Processing Record 33 of Set 6 | monastyryshche
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | khandbari
# Processing Record 36 of Set 6 | minggang
# Processing Record 37 of Set 6 | healesville
# Processing Record 38 of Set 6 | ponta delgada
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | nanortalik
# Processing Record 41 of Set 6 | beidao
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | kudat
# Processing Record 45 of Set 6 | manado
# Processing Record 46 of Set 6 | baruun-urt
# Processing Record 47 of Set 6 | araouane
# Processing Record 48 of Set 6 | sovetskiy
# Processing Record 49 of Set 6 | tolosa
# Processing Record 50 of Set 6 | fallon
# Processing Record 1 of Set 7 | mihijam
# Processing Record 2 of Set 7 | montefiascone
# Processing Record 3 of Set 7 | erzin
# Processing Record 4 of Set 7 | les cayes
# Processing Record 5 of Set 7 | teluknaga
# Processing Record 6 of Set 7 | broken hill
# Processing Record 7 of Set 7 | smalininkai
# Processing Record 8 of Set 7 | pisek
# Processing Record 9 of Set 7 | straumen
# Processing Record 10 of Set 7 | harper
# Processing Record 11 of Set 7 | gambela
# Processing Record 12 of Set 7 | mao
# Processing Record 13 of Set 7 | yeppoon
# Processing Record 14 of Set 7 | romans-sur-isere
# Processing Record 15 of Set 7 | pacific grove
# Processing Record 16 of Set 7 | fortuna foothills
# Processing Record 17 of Set 7 | anloga
# Processing Record 18 of Set 7 | abalak
# Processing Record 19 of Set 7 | amapa
# Processing Record 20 of Set 7 | jalapa
# Processing Record 21 of Set 7 | lata
# Processing Record 22 of Set 7 | maceio
# Processing Record 23 of Set 7 | shingu
# Processing Record 24 of Set 7 | beringovskiy
# Processing Record 25 of Set 7 | elizabeth city
# Processing Record 26 of Set 7 | ilulissat
# Processing Record 27 of Set 7 | turukhansk
# Processing Record 28 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 29 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | hasaki
# Processing Record 33 of Set 7 | taoudenni
# Processing Record 34 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | southbridge
# Processing Record 37 of Set 7 | biak
# Processing Record 38 of Set 7 | chicama
# Processing Record 39 of Set 7 | beloha
# Processing Record 40 of Set 7 | grindavik
# Processing Record 41 of Set 7 | antalaha
# Processing Record 42 of Set 7 | gemena
# Processing Record 43 of Set 7 | badvel
# Processing Record 44 of Set 7 | antofagasta
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | tartagal
# Processing Record 47 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 7 | rosetta
# Processing Record 49 of Set 7 | namalenga
# Processing Record 50 of Set 7 | vanimo
# Processing Record 1 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | la palma
# Processing Record 4 of Set 8 | cedro
# Processing Record 5 of Set 8 | waipawa
# Processing Record 6 of Set 8 | salinopolis
# Processing Record 7 of Set 8 | tarija
# Processing Record 8 of Set 8 | passo de camaragibe
# Processing Record 9 of Set 8 | joshimath
# Processing Record 10 of Set 8 | hofn
# Processing Record 11 of Set 8 | inta
# Processing Record 12 of Set 8 | lorengau
# Processing Record 13 of Set 8 | alvorada
# Processing Record 14 of Set 8 | viedma
# Processing Record 15 of Set 8 | altay
# Processing Record 16 of Set 8 | chesterville
# Processing Record 17 of Set 8 | sharan
# Processing Record 18 of Set 8 | shitanjing
# Processing Record 19 of Set 8 | mersing
# Processing Record 20 of Set 8 | touros
# Processing Record 21 of Set 8 | fare
# Processing Record 22 of Set 8 | marawi
# Processing Record 23 of Set 8 | aswan
# Processing Record 24 of Set 8 | moquegua
# Processing Record 25 of Set 8 | salinas
# Processing Record 26 of Set 8 | atar
# Processing Record 27 of Set 8 | merauke
# Processing Record 28 of Set 8 | iqaluit
# Processing Record 29 of Set 8 | ploemeur
# Processing Record 30 of Set 8 | mujiayingzi
# Processing Record 31 of Set 8 | toccoa
# Processing Record 32 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 8 | seymchan
# Processing Record 34 of Set 8 | iberia
# Processing Record 35 of Set 8 | yenagoa
# Processing Record 36 of Set 8 | butterworth
# Processing Record 37 of Set 8 | adeje
# Processing Record 38 of Set 8 | melrose
# Processing Record 39 of Set 8 | pereira barreto
# Processing Record 40 of Set 8 | saldanha
# Processing Record 41 of Set 8 | sylacauga
# Processing Record 42 of Set 8 | hualmay
# Processing Record 43 of Set 8 | havelock
# Processing Record 44 of Set 8 | darab
# Processing Record 45 of Set 8 | ati
# Processing Record 46 of Set 8 | jalu
# Processing Record 47 of Set 8 | gizo
# Processing Record 48 of Set 8 | formosa
# Processing Record 49 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 8 | tecpan
# Processing Record 1 of Set 9 | ocos
# Processing Record 2 of Set 9 | grand gaube
# Processing Record 3 of Set 9 | leshukonskoye
# Processing Record 4 of Set 9 | stornoway
# Processing Record 5 of Set 9 | perevoz
# Processing Record 6 of Set 9 | maniitsoq
# Processing Record 7 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 9 | marzuq
# Processing Record 9 of Set 9 | bontang
# Processing Record 10 of Set 9 | arlit
# Processing Record 11 of Set 9 | takoradi
# Processing Record 12 of Set 9 | puerto del rosario
# Processing Record 13 of Set 9 | arrecife
# Processing Record 14 of Set 9 | namtsy
# Processing Record 15 of Set 9 | piryion
# City not found. Skipping...
# Processing Record 16 of Set 9 | vila
# Processing Record 17 of Set 9 | kununurra
# Processing Record 18 of Set 9 | benjamin constant
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | lastoursville
# Processing Record 21 of Set 9 | bethanien
# Processing Record 22 of Set 9 | kirovskiy
# Processing Record 23 of Set 9 | shadegan
# Processing Record 24 of Set 9 | mana
# Processing Record 25 of Set 9 | ambon
# Processing Record 26 of Set 9 | charlottetown
# Processing Record 27 of Set 9 | batagay
# Processing Record 28 of Set 9 | takhatgarh
# Processing Record 29 of Set 9 | bacolod
# Processing Record 30 of Set 9 | marystown
# Processing Record 31 of Set 9 | santa catalina
# Processing Record 32 of Set 9 | port keats
# Processing Record 33 of Set 9 | estevan
# Processing Record 34 of Set 9 | rampura
# Processing Record 35 of Set 9 | hohhot
# Processing Record 36 of Set 9 | pakhtakoron
# Processing Record 37 of Set 9 | marsh harbour
# Processing Record 38 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 9 | odesa
# Processing Record 41 of Set 9 | saint-georges
# Processing Record 42 of Set 9 | sumter
# Processing Record 43 of Set 9 | walvis bay
# Processing Record 44 of Set 9 | palmer
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | poum
# Processing Record 47 of Set 9 | kesova gora
# Processing Record 48 of Set 9 | mekhe
# Processing Record 49 of Set 9 | ulyanovo
# City not found. Skipping...
# Processing Record 50 of Set 9 | uglegorsk
# Processing Record 1 of Set 10 | san cristobal
# Processing Record 2 of Set 10 | mackenzie
# Processing Record 3 of Set 10 | darlawn
# Processing Record 4 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 10 | port pirie
# Processing Record 6 of Set 10 | maiduguri
# Processing Record 7 of Set 10 | nalut
# Processing Record 8 of Set 10 | kargala
# Processing Record 9 of Set 10 | yashkul
# Processing Record 10 of Set 10 | bulawayo
# Processing Record 11 of Set 10 | bukama
# Processing Record 12 of Set 10 | remontnoye
# Processing Record 13 of Set 10 | bull savanna
# Processing Record 14 of Set 10 | eyl
# Processing Record 15 of Set 10 | auki
# Processing Record 16 of Set 10 | lipari
# Processing Record 17 of Set 10 | birjand
# Processing Record 18 of Set 10 | hobyo
# Processing Record 19 of Set 10 | berdigestyakh
# Processing Record 20 of Set 10 | kismayo
# Processing Record 21 of Set 10 | nyrob
# Processing Record 22 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 10 | tual
# Processing Record 24 of Set 10 | srinagar
# Processing Record 25 of Set 10 | boa vista
# Processing Record 26 of Set 10 | mitsamiouli
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | alta floresta
# Processing Record 29 of Set 10 | nargana
# Processing Record 30 of Set 10 | at-bashi
# Processing Record 31 of Set 10 | murgab
# Processing Record 32 of Set 10 | okoneshnikovo
# Processing Record 33 of Set 10 | coihaique
# Processing Record 34 of Set 10 | san joaquin
# Processing Record 35 of Set 10 | toktogul
# Processing Record 36 of Set 10 | nakatsu
# Processing Record 37 of Set 10 | mount isa
# Processing Record 38 of Set 10 | gunjur
# Processing Record 39 of Set 10 | mantua
# Processing Record 40 of Set 10 | ust-maya
# Processing Record 41 of Set 10 | de-kastri
# Processing Record 42 of Set 10 | conakry
# Processing Record 43 of Set 10 | chapleau
# Processing Record 44 of Set 10 | kumta
# Processing Record 45 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | santa rosa
# Processing Record 48 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 49 of Set 10 | ossora
# Processing Record 50 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 11 | manokwari
# Processing Record 2 of Set 11 | kamiiso
# Processing Record 3 of Set 11 | jishou
# Processing Record 4 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 5 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 11 | acaponeta
# Processing Record 7 of Set 11 | sitka
# Processing Record 8 of Set 11 | kashi
# Processing Record 9 of Set 11 | osa
# Processing Record 10 of Set 11 | talnakh
# Processing Record 11 of Set 11 | walla walla
# Processing Record 12 of Set 11 | san juan
# Processing Record 13 of Set 11 | subottsi
# Processing Record 14 of Set 11 | hay river
# Processing Record 15 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 16 of Set 11 | sabang
# Processing Record 17 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 18 of Set 11 | zaozerne
# Processing Record 19 of Set 11 | yarkovo
# Processing Record 20 of Set 11 | doha
# Processing Record 21 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 11 | cruzeiro do sul
# Processing Record 23 of Set 11 | jacqueville
# Processing Record 24 of Set 11 | le port
# Processing Record 25 of Set 11 | save
# Processing Record 26 of Set 11 | zhangye
# Processing Record 27 of Set 11 | esso
# Processing Record 28 of Set 11 | hamilton
# Processing Record 29 of Set 11 | hovd
# Processing Record 30 of Set 11 | hammerfest
# Processing Record 31 of Set 11 | lagoa
# Processing Record 32 of Set 11 | khandyga
# Processing Record 33 of Set 11 | axim
# Processing Record 34 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 11 | palauig
# Processing Record 36 of Set 11 | almaznyy
# Processing Record 37 of Set 11 | constitucion
# Processing Record 38 of Set 11 | fort nelson
# Processing Record 39 of Set 11 | noumea
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | bongandanga
# Processing Record 42 of Set 11 | igarape-acu
# City not found. Skipping...
# Processing Record 43 of Set 11 | kavaratti
# Processing Record 44 of Set 11 | marsa matruh
# Processing Record 45 of Set 11 | ixtapa
# Processing Record 46 of Set 11 | pedernales
# Processing Record 47 of Set 11 | namestovo
# Processing Record 48 of Set 11 | acapulco
# Processing Record 49 of Set 11 | pokhara
# Processing Record 50 of Set 11 | nipawin
# Processing Record 1 of Set 12 | zambezi
# Processing Record 2 of Set 12 | parkes
# Processing Record 3 of Set 12 | hambantota
# Processing Record 4 of Set 12 | hyeres
# Processing Record 5 of Set 12 | eureka
# Processing Record 6 of Set 12 | resistencia
# Processing Record 7 of Set 12 | hervey bay
# Processing Record 8 of Set 12 | paithan
# Processing Record 9 of Set 12 | toro
# Processing Record 10 of Set 12 | razole
# Processing Record 11 of Set 12 | pandan
# Processing Record 12 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 13 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 12 | gimli
# Processing Record 15 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 12 | potsdam
# Processing Record 17 of Set 12 | najran
# Processing Record 18 of Set 12 | sabancuy
# Processing Record 19 of Set 12 | vyartsilya
# Processing Record 20 of Set 12 | mayo
# Processing Record 21 of Set 12 | samarai
# Processing Record 22 of Set 12 | port shepstone
# Processing Record 23 of Set 12 | belyy yar
# Processing Record 24 of Set 12 | novikovo
# Processing Record 25 of Set 12 | yabrud
# Processing Record 26 of Set 12 | bardiyah
# Processing Record 27 of Set 12 | cabedelo
# Processing Record 28 of Set 12 | ontario
# Processing Record 29 of Set 12 | kerrville
# Processing Record 30 of Set 12 | liverpool
# Processing Record 31 of Set 12 | monrovia
# Processing Record 32 of Set 12 | buraydah
# Processing Record 33 of Set 12 | wynyard
# Processing Record 34 of Set 12 | chara
# Processing Record 35 of Set 12 | puerto madryn
# Processing Record 36 of Set 12 | shirokiy
# Processing Record 37 of Set 12 | yertsevo
# Processing Record 38 of Set 12 | hirado
# Processing Record 39 of Set 12 | rudnaya pristan
# Processing Record 40 of Set 12 | plettenberg bay
# Processing Record 41 of Set 12 | sao paulo de olivenca
# Processing Record 42 of Set 12 | sao francisco de paula
# Processing Record 43 of Set 12 | cobh
# Processing Record 44 of Set 12 | kota belud
# Processing Record 45 of Set 12 | jennings
# Processing Record 46 of Set 12 | sebinkarahisar
# Processing Record 47 of Set 12 | muisne
# Processing Record 48 of Set 12 | zalesovo
# Processing Record 49 of Set 12 | buin
# Processing Record 50 of Set 12 | mutsu
# Processing Record 1 of Set 13 | sohag
# Processing Record 2 of Set 13 | vila franca do campo
# Processing Record 3 of Set 13 | yar-sale
# Processing Record 4 of Set 13 | irtyshskiy
# Processing Record 5 of Set 13 | penzance
# Processing Record 6 of Set 13 | manavgat
# Processing Record 7 of Set 13 | lao cai
# Processing Record 8 of Set 13 | berlevag
# Processing Record 9 of Set 13 | redlands
# Processing Record 10 of Set 13 | lavrentiya
# Processing Record 11 of Set 13 | manono
# Processing Record 12 of Set 13 | nguruka
# Processing Record 13 of Set 13 | chingola
# Processing Record 14 of Set 13 | savona
# Processing Record 15 of Set 13 | bend
# Processing Record 16 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 13 | zvenigovo
# Processing Record 18 of Set 13 | uhlove
# Processing Record 19 of Set 13 | ilo
# Processing Record 20 of Set 13 | terrak
# Processing Record 21 of Set 13 | sibiti
# Processing Record 22 of Set 13 | ararangua
# Processing Record 23 of Set 13 | aquiraz
# Processing Record 24 of Set 13 | mildura
# Processing Record 25 of Set 13 | bulgan
# Processing Record 26 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 13 | mercedes
# Processing Record 28 of Set 13 | la linea
# Processing Record 29 of Set 13 | seydi
# Processing Record 30 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 13 | omsukchan
# Processing Record 32 of Set 13 | nara
# Processing Record 33 of Set 13 | ratnagiri
# Processing Record 34 of Set 13 | vardo
# Processing Record 35 of Set 13 | winslow
# Processing Record 36 of Set 13 | kalat
# Processing Record 37 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 13 | sidi ali
# Processing Record 39 of Set 13 | bilma
# Processing Record 40 of Set 13 | rawson
# Processing Record 41 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 42 of Set 13 | daru
# Processing Record 43 of Set 13 | guaruja
# Processing Record 44 of Set 13 | dingli
# Processing Record 45 of Set 13 | sakaiminato
# Processing Record 46 of Set 13 | coihueco
# Processing Record 47 of Set 13 | kushima
# Processing Record 48 of Set 13 | ulaangom
# Processing Record 49 of Set 13 | whakatane
# Processing Record 50 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 14 | nagahama
# Processing Record 2 of Set 14 | baranoa
# Processing Record 3 of Set 14 | oistins
# Processing Record 4 of Set 14 | takefu
# Processing Record 5 of Set 14 | nouadhibou
# Processing Record 6 of Set 14 | tlapehuala
# Processing Record 7 of Set 14 | winnemucca
# Processing Record 8 of Set 14 | togur
# Processing Record 9 of Set 14 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 10 of Set 14 | vangaindrano
# Processing Record 11 of Set 14 | celestun
# Processing Record 12 of Set 14 | surt
# Processing Record 13 of Set 14 | xining
# Processing Record 14 of Set 14 | kruisfontein
# Processing Record 15 of Set 14 | shaowu
# Processing Record 16 of Set 14 | ewa beach
# Processing Record 17 of Set 14 | ogulin
# Processing Record 18 of Set 14 | kulhudhuffushi
# Processing Record 19 of Set 14 | weyburn
# Processing Record 20 of Set 14 | tessalit
# Processing Record 21 of Set 14 | bredy
# Processing Record 22 of Set 14 | montepuez
# Processing Record 23 of Set 14 | zhangjiakou
# Processing Record 24 of Set 14 | swadlincote
# Processing Record 25 of Set 14 | kondinskoye
# Processing Record 26 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 14 | mitchell
# Processing Record 28 of Set 14 | quelimane
# Processing Record 29 of Set 14 | morant bay
# Processing Record 30 of Set 14 | dasoguz
# Processing Record 31 of Set 14 | vao
# Processing Record 32 of Set 14 | sioux lookout
# Processing Record 33 of Set 14 | copiapo
# Processing Record 34 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 14 | sur
# Processing Record 36 of Set 14 | westport
# Processing Record 37 of Set 14 | tierranueva
# Processing Record 38 of Set 14 | talcahuano
# Processing Record 39 of Set 14 | novaya ladoga
# Processing Record 40 of Set 14 | chinsali
# Processing Record 41 of Set 14 | bereda
# Processing Record 42 of Set 14 | buluang
# Processing Record 43 of Set 14 | ryotsu
# Processing Record 44 of Set 14 | zeya
# Processing Record 45 of Set 14 | kolding
# Processing Record 46 of Set 14 | acajutla
# Processing Record 47 of Set 14 | kotma
# Processing Record 48 of Set 14 | laguna
# Processing Record 49 of Set 14 | buala
# Processing Record 50 of Set 14 | port hardy
# Processing Record 1 of Set 15 | ulaanbaatar
# Processing Record 2 of Set 15 | bonfim
# Processing Record 3 of Set 15 | adre
# Processing Record 4 of Set 15 | namibe
# Processing Record 5 of Set 15 | urumqi
# Processing Record 6 of Set 15 | qaqortoq
# Processing Record 7 of Set 15 | konskie
# Processing Record 8 of Set 15 | tilichiki
# Processing Record 9 of Set 15 | riviere-au-renard
# Processing Record 10 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 15 | wattegama
# Processing Record 12 of Set 15 | sorland
# Processing Record 13 of Set 15 | luderitz
# Processing Record 14 of Set 15 | baijiantan
# Processing Record 15 of Set 15 | danielskuil
# Processing Record 16 of Set 15 | tayu
# Processing Record 17 of Set 15 | ketchikan
# Processing Record 18 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 15 | ginir
# Processing Record 20 of Set 15 | viru
# Processing Record 21 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 22 of Set 15 | griffith
# Processing Record 23 of Set 15 | ormara
# Processing Record 24 of Set 15 | kamenka
# Processing Record 25 of Set 15 | komsomolskiy
# Processing Record 26 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 15 | paidha
# Processing Record 28 of Set 15 | dingle
# Processing Record 29 of Set 15 | clyde river
# Processing Record 30 of Set 15 | qarqin
# Processing Record 31 of Set 15 | atasu
# Processing Record 32 of Set 15 | honningsvag
# Processing Record 33 of Set 15 | emba
# Processing Record 34 of Set 15 | keetmanshoop
# Processing Record 35 of Set 15 | moussoro
# Processing Record 36 of Set 15 | kuching
# Processing Record 37 of Set 15 | qandala
# Processing Record 38 of Set 15 | pozoblanco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert to dataframe

weather_database_df = pd.DataFrame(city_data)
weather_database_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Batagay-Alyta      RU  67.80  130.41      4.78        93         100
# 1          Hobart      AU -42.88  147.33     53.60        81          75
# 2        Pasighat      IN  28.07   95.33     68.74        42           2
# 3  Port Elizabeth      ZA -33.92   25.57     59.00        77         100
# 4           Bluff      NZ -46.60  168.33     54.00        91         100
# 5            Mega      ET   4.05   38.30     59.88        96          60
# 6            Hilo      US  19.73 -155.09     78.80        65          75
# 7         Saurimo      AO  -9.66   20.39     68.16        86          17
# 8         Ushuaia      AR -54.80  -68.30     46.40        75          75
# 9         Kavieng      PG  -2.57  150.80     81.25        75         100
#
#    Wind Speed Current Description
# 0        2.10          light snow
# 1        3.36       broken clouds
# 2        4.21           clear sky
# 3       20.80     overcast clouds
# 4        1.99     overcast clouds
# 5       11.12       broken clouds
# 6        3.36       broken clouds
# 7        2.68          few clouds
# 8       32.21       broken clouds
# 9        4.45          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
